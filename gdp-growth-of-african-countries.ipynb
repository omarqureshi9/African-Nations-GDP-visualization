# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/kaggle/input/gdp-growth-of-african-countries/Africa_GDP.csv')
dataset
# Out:
#     Year       Algeria         Benin      Botswana  Burkina Faso  \
# 0   1960  2.723615e+09  2.261956e+08  3.041141e+07  3.304428e+08
# 1   1961  2.434747e+09  2.356682e+08  3.290261e+07  3.502472e+08
# 2   1962  2.001445e+09  2.364350e+08  3.564496e+07  3.795671e+08
# 3   1963  2.702982e+09  2.539277e+08  3.809184e+07  3.940407e+08
# 4   1964  2.909316e+09  2.698190e+08  4.161635e+07  4.103216e+08
# ..   ...           ...           ...           ...           ...
# 59  2019  1.934600e+11  1.439071e+10  1.672591e+10  1.603281e+10
# 60  2020  1.648730e+11  1.568674e+10  1.496029e+10  1.772501e+10
# 61  2021  1.862650e+11  1.768762e+10  1.875095e+10  1.964317e+10
# 62  2022  2.255600e+11  1.742542e+10  2.032196e+10  1.882022e+10
# 63  2023  2.398990e+11  1.967328e+10  1.939577e+10  2.032462e+10
#
#          Burundi      Cameroon  Central African Republic          Chad  \
# 0   1.960000e+08  6.142061e+08              1.121556e+08  3.135827e+08
# ...

# %%
dataset.describe()
# Out:
#               Year       Algeria         Benin      Botswana  Burkina Faso  \
# count    64.000000  6.400000e+01  6.400000e+01  6.400000e+01  6.400000e+01
# mean   1991.500000  7.971055e+10  4.706354e+09  5.823204e+09  5.154302e+09
# std      18.618987  7.622340e+10  5.452323e+09  6.239429e+09  5.770365e+09
# min    1960.000000  2.001445e+09  2.261956e+08  3.041141e+07  3.304428e+08
# 25%    1975.750000  1.718566e+10  6.930237e+08  3.678110e+08  9.674036e+08
# 50%    1991.500000  4.937348e+10  1.827640e+09  4.044671e+09  2.601069e+09
# 75%    2007.250000  1.444415e+11  8.510623e+09  1.023066e+10  8.081966e+09
# max    2023.000000  2.398990e+11  1.967328e+10  2.032196e+10  2.032462e+10
#
#             Burundi      Cameroon  Central African Republic          Chad  \
# count  6.400000e+01  6.400000e+01              6.400000e+01  6.400000e+01
# mean   1.170612e+09  1.484101e+10              1.097358e+09  4.011726e+09
# ...

# %%
data=dataset.copy()
dataset.dtypes
# Out:
# Year                          int64
# Algeria                     float64
# Benin                       float64
# Botswana                    float64
# Burkina Faso                float64
# Burundi                     float64
# Cameroon                    float64
# Central African Republic    float64
# Chad                        float64
# Eswatini                    float64
# Ethiopia                    float64
# Gabon                       float64
# Ghana                       float64
# Kenya                       float64
# Lesotho                     float64
# Liberia                     float64
# Libya                       float64
# Madagascar                  float64
# Mauritius                   float64
# Morocco                     float64
# Niger                       float64
# Nigeria                     float64
# Rwanda                      float64
# Senegal                     float64
# Seychelles                  float64
# Sierra Leone                float64
# ...

# %%
data.isnull().sum()
# Out:
# Year                        0
# Algeria                     0
# Benin                       0
# Botswana                    0
# Burkina Faso                0
# Burundi                     0
# Cameroon                    0
# Central African Republic    0
# Chad                        0
# Eswatini                    0
# Ethiopia                    0
# Gabon                       0
# Ghana                       0
# Kenya                       0
# Lesotho                     0
# Liberia                     0
# Libya                       0
# Madagascar                  0
# Mauritius                   0
# Morocco                     0
# Niger                       0
# Nigeria                     0
# Rwanda                      0
# Senegal                     0
# Seychelles                  0
# Sierra Leone                0
# Somalia                     0
# South Africa                0
# Sudan                       0
# Tanzania                    0
# Togo                        0
# ...

# %%
pivot_table = pd.pivot_table(data, index="Year", aggfunc="sum")

# %%
pivot_table
# Out:
#            Algeria         Benin      Botswana  Burkina Faso       Burundi  \
# Year
# 1960  2.723615e+09  2.261956e+08  3.041141e+07  3.304428e+08  1.960000e+08
# 1961  2.434747e+09  2.356682e+08  3.290261e+07  3.502472e+08  2.030000e+08
# 1962  2.001445e+09  2.364350e+08  3.564496e+07  3.795671e+08  2.135000e+08
# 1963  2.702982e+09  2.539277e+08  3.809184e+07  3.940407e+08  2.327500e+08
# 1964  2.909316e+09  2.698190e+08  4.161635e+07  4.103216e+08  2.607500e+08
# ...            ...           ...           ...           ...           ...
# 2019  1.934600e+11  1.439071e+10  1.672591e+10  1.603281e+10  2.576519e+09
# 2020  1.648730e+11  1.568674e+10  1.496029e+10  1.772501e+10  2.649680e+09
# 2021  1.862650e+11  1.768762e+10  1.875095e+10  1.964317e+10  2.775799e+09
# 2022  2.255600e+11  1.742542e+10  2.032196e+10  1.882022e+10  3.338723e+09
# 2023  2.398990e+11  1.967328e+10  1.939577e+10  2.032462e+10  2.642162e+09
#
# ...

# %%
sns.heatmap(pivot_table);
